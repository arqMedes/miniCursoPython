# %% [markdown]
# # Matplotlib
#
#
# https://www.alura.com.br/artigos/criando-graficos-no-python-com-a-matplotlib
#
# https://www.vooo.pro/insights/guia-basico-para-plotar-graficos-usando-o-matplotlib-do-python/
#
# [Apostila](pdf/matplotlibAp.pdf)

# %%
import matplotlib.pylab as pln
import numpy as np

x = np.arange(10)
y = x**2
pln.grid()
pln.axis((0,10, 0, 100))
pln.plot(x, y, 'b-.')

# %%
def f(x):
    return 1./x**2 + 6

# %%
X = np.linspace(-50, 50, num=100)
Y = f(X)

# %%
pln.plot(X, Y)
pln.grid()

# %%
t = np.linspace(0, 50e-3, num = 200)

a = 311*np.sin(377*t)
b = 311*np.sin(377*t - np.pi*2/3)
c = 311*np.sin(377*t + np.pi*2/3)

pln.plot(t, a, t, b, t, c)

# %%
# lendo dados do arquivo txt x;y
X = []
Y = []
for e in open("dadosLab.txt", "r"):
    L = e.split(";")
    x = float(L[0])
    y = float(L[1])
    X.append(x)
    Y.append(y)
pln.plot(X, Y, 'k-.')

# %%
e = "11; 11.1"
L = e.split(";")
print(L)
# Out:
# ['11', ' 11.1']

# %%
float(L[1])
# Out:
# 11.1
